# %% [markdown]
# <!-- Centered Title -->
# <h1 style="color: #1f4e79;
#            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#            text-align: center;">
# Cryptocurrency Web Scraping Project
# </h1>
#
# <!-- Left-aligned bullet points -->
# <ul style="text-align: left;
#            color: #333333;
#            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#            line-height: 1.6;
#            margin-top: 10px;">
#   <li>This notebook collects historical cryptocurrency data (top 10 coins) from CoinMarketCap.</li>
#   <li>The goal is to extract, clean, and structure the data before saving it as a CSV for further processing.</li>
# </ul>

# %% [markdown]
# ## Importing Required Libraries
#
# In this block, we import all the necessary Python libraries for our project:
#
# - `requests`: To send HTTP requests and fetch HTML content from websites.
# - `BeautifulSoup` from `bs4`: To parse and extract data from HTML pages.
# - `pandas`: For data manipulation and storage in DataFrame format.
# - `KNNImputer` from `sklearn.impute`: To handle missing values in numerical columns using K-Nearest Neighbors imputation.
# - `MinMaxScaler` from `sklearn.preprocessing`: To normalize numerical features before applying imputation.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Extraction
#
# ### 1.1 Initializing Data Lists and Creating DataFrame
#
# Before scraping cryptocurrency data, we initialize empty lists for each feature we want to collect. These lists will store data for:
#
# - `crypto_date_list` : Date of the data snapshot
# - `crypto_name_list` : Name of the cryptocurrency
# - `crypto_symbol_list` : Symbol of the cryptocurrency
# - `crypto_market_cap_list` : Market capitalization
# - `crypto_price_list` : Current price
# - `crypto_circulating_supply_list` : Circulating supply of the coin
# - `crypto_voulume_24hr_list` : Trading volume in the last 24 hours
# - `crypto_pct_1hr_list` : Percentage change in 1 hour
# - `crypto_pct_24hr_list` : Percentage change in 24 hours
# - `crypto_pct_7day_list` : Percentage change in 7 days
#
# We also create an empty pandas DataFrame `df` which will later store all this collected data in tabular format.

# %%
# Initializing lists to store cryptocurrency data
crypto_date_list = []
crypto_name_list = []
crypto_symbol_list = []
crypto_market_cap_list = []
crypto_price_list = []
crypto_circulating_supply_list = []
crypto_voulume_24hr_list = []
crypto_pct_1hr_list = []
crypto_pct_24hr_list = []
crypto_pct_7day_list = []

# Creating an empty DataFrame to hold the scraped data
df = pd.DataFrame()

# %% [markdown]
# ### 1.2 Function: Scrape Date List from CoinMarketCap
#
# To collect historical cryptocurrency data, we first need the list of dates for which data is available. CoinMarketCap provides historical snapshots, typically taken on Sundays.
#
# - We define an empty list `scrape_date_list` to store these URLs.
# - The function `scrape_date()` performs the following:
#   1. Sends a GET request to the CoinMarketCap historical page.
#   2. Parses the HTML content using BeautifulSoup.
#   3. Finds all `<a>` tags with the class `'historical-link cmc-link'`, which correspond to the available dates.
#   4. Extracts the `href` attribute from each tag and appends it to `scrape_date_list`.
#
# After running the function, we print the total number of dates (Sundays) available for scraping.

# %%
# List to store historical data URLs
scrape_date_list = []

# Function to scrape available historical data dates (Sundays)
def scrape_date():
    url = 'https://coinmarketcap.com/historical/'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    a_tags = soup.find_all('a', class_='historical-link cmc-link')
    for tag in a_tags:
        href = tag.get('href')
        scrape_date_list.append(href)

# Execute the function to collect all available historical data URLs
scrape_date()
print('There are ' + str(len(scrape_date_list)) + ' dates(Sundays) available for scraping from CoinMarketCap historical data.')
# Out:
# There are 659 dates(Sundays) available for scraping from CoinMarketCap historical data.

# %% [markdown]
# ### 1.3 Scrape Cryptocurrency Data for a Specific Date
#
# The following function `scrape_data(date)` is designed to extract the top 10 cryptocurrencies by market capitalization for a given historical date from CoinMarketCap.
#
# **Function Overview:**
#
# - **Input:** `date` (string) — the historical date URL path from CoinMarketCap.
# - **Process:**
#   - Send a request to the specific historical page.
#   - Parse the HTML using BeautifulSoup.
#   - Iterate through the table rows to extract details of the top 10 cryptocurrencies.
#   - Handle missing data gracefully using `try-except` blocks for each field.
# - **Output:** Data is appended to the respective lists initialized earlier for further processing and creation of a DataFrame.
#
# The extracted fields include:
# - Date
# - Cryptocurrency Name
# - Symbol
# - Market Capitalization
# - Price
# - Circulating Supply
# - 24-hour Trading Volume
# - Percentage change over 1 hour, 24 hours, and 7 days

# %%
def scrape_data(date):

    """
    Scrapes the top 10 cryptocurrencies for a specific historical date from CoinMarketCap.
    
    Parameters:
    date (str): The historical date URL path (e.g., '/historical/20251201/')
    
    The function updates the global lists initialized earlier.
    """
    
    url = 'https://coinmarketcap.com' + date
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    tr = soup.find_all('tr', attrs={'class': 'cmc-table-row'})
    count = 0
    for row in tr:
        if count == 10:
            break
        count += 1

        try:
            crypto_date = date
        except AttributeError:
            crypto_date = None

        try:
            name_column = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sticky cmc-table__cell--sortable cmc-table__cell--left cmc-table__cell--sort-by__name'})
            crypto_name = name_column.find('a', attrs={'class': 'cmc-table__column-name--name cmc-link'}).text.strip()
        except AttributeError:
            crypto_name = None

        try:
            crypto_symbol = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--left cmc-table__cell--sort-by__symbol'}).text.strip()
        except AttributeError:
            crypto_symbol = None

        try:
            crypto_market_cap = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__market-cap'}).text.strip()
        except AttributeError:
            crypto_market_cap = None

        try:
            crypto_price = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__price'}).text.strip()
        except AttributeError:
            crypto_price = None

        try:
            crypto_circulating_supply = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__circulating-supply'}).text.strip().split(' ')[0]
        except AttributeError:
            crypto_circulating_supply = None

        try:
            crypto_voulume_24hr_td = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__volume-24-h'})
            crypto_voulume_24hr = crypto_voulume_24hr_td.find('a', attrs={'class': 'cmc-link'}).text.strip()
        except AttributeError:
            crypto_voulume_24hr = None

        try:
            crypto_pct_1hr = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__percent-change-1-h'}).text.strip()
        except AttributeError:
            crypto_pct_1hr = None

        try:
            crypto_pct_24hr = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__percent-change-24-h'}).text.strip()
        except AttributeError:
            crypto_pct_24hr = None

        try:
            crypto_pct_7day = row.find('td', attrs={'class': 'cmc-table__cell cmc-table__cell--sortable cmc-table__cell--right cmc-table__cell--sort-by__percent-change-7-d'}).text.strip()
        except AttributeError:
            crypto_pct_7day = None
            
        # Append extracted data to global lists
        crypto_date_list.append(crypto_date)
        crypto_name_list.append(crypto_name)
        crypto_symbol_list.append(crypto_symbol)
        crypto_market_cap_list.append(crypto_market_cap)
        crypto_price_list.append(crypto_price)
        crypto_circulating_supply_list.append(crypto_circulating_supply)
        crypto_voulume_24hr_list.append(crypto_voulume_24hr)
        crypto_pct_1hr_list.append(crypto_pct_1hr)
        crypto_pct_24hr_list.append(crypto_pct_24hr)
        crypto_pct_7day_list.append(crypto_pct_7day)

# %% [markdown]
# ### 1.4 Scraping Cryptocurrency Data for Multiple Dates
#
# Once we have collected all available historical date URLs from CoinMarketCap, we can iterate over these dates to scrape the cryptocurrency data for each one.
#
# **Steps:**
#
# 1. Convert the start and end date from the scraped URLs to a readable format (`YYYY-MM-DD`) for display.
# 2. Print the total number of available dates to scrape.
# 3. Loop through each date URL in `scrape_date_list`, calling the `scrape_data()` function to extract top 10 cryptocurrencies for each date.
# 4. Display progress in the console to track scraping status.

# %%
from datetime import datetime
# Define the date format for conversion
date_format = "%Y%m%d"

# Convert start and end dates from the scrape_date_list URLs
start_date = datetime.strptime(scrape_date_list[0].split('/')[-2], date_format).strftime('%Y-%m-%d')
end_date = datetime.strptime(scrape_date_list[-1].split('/')[-2], date_format).strftime('%Y-%m-%d')
print('There are ' + str(len(scrape_date_list)) + ' dates(Sundays) between ' + start_date + ' and ' + end_date)

# Loop through all historical dates and scrape cryptocurrency data
for i in range(len(scrape_date_list)):
    scrape_data(scrape_date_list[i])
    print("completed: " + str(i+1) + " out of " + str(len(scrape_date_list)))
# Out:
# There are 659 dates(Sundays) between 2013-04-28 and 2025-12-07
# completed: 1 out of 659
# completed: 2 out of 659
# completed: 3 out of 659
# completed: 4 out of 659
# completed: 5 out of 659
# completed: 6 out of 659
# completed: 7 out of 659
# completed: 8 out of 659
# completed: 9 out of 659
# completed: 10 out of 659
# completed: 11 out of 659
# completed: 12 out of 659
# completed: 13 out of 659
# completed: 14 out of 659
# completed: 15 out of 659
# completed: 16 out of 659
# completed: 17 out of 659
# completed: 18 out of 659
# completed: 19 out of 659
# completed: 20 out of 659
# completed: 21 out of 659
# completed: 22 out of 659
# completed: 23 out of 659
# completed: 24 out of 659
# completed: 25 out of 659
# completed: 26 out of 659
# completed: 27 out of 659
# completed: 28 out of 659
# completed: 29 out of 659
# completed: 30 out of 659
# completed: 31 out of 659
# completed: 32 out of 659
# completed: 33 out of 659
# completed: 34 out of 659
# completed: 35 out of 659
# completed: 36 out of 659
# completed: 37 out of 659
# completed: 38 out of 659
# completed: 39 out of 659
# completed: 40 out of 659
# completed: 41 out of 659
# completed: 42 out of 659
# completed: 43 out of 659
# completed: 44 out of 659
# completed: 45 out of 659
# completed: 46 out of 659
# completed: 47 out of 659
# completed: 48 out of 659
# completed: 49 out of 659
# completed: 50 out of 659
# completed: 51 out of 659
# completed: 52 out of 659
# completed: 53 out of 659
# completed: 54 out of 659
# completed: 55 out of 659
# completed: 56 out of 659
# completed: 57 out of 659
# completed: 58 out of 659
# completed: 59 out of 659
# completed: 60 out of 659
# completed: 61 out of 659
# completed: 62 out of 659
# completed: 63 out of 659
# completed: 64 out of 659
# completed: 65 out of 659
# completed: 66 out of 659
# completed: 67 out of 659
# completed: 68 out of 659
# completed: 69 out of 659
# completed: 70 out of 659
# completed: 71 out of 659
# completed: 72 out of 659
# completed: 73 out of 659
# completed: 74 out of 659
# completed: 75 out of 659
# completed: 76 out of 659
# completed: 77 out of 659
# completed: 78 out of 659
# completed: 79 out of 659
# completed: 80 out of 659
# completed: 81 out of 659
# completed: 82 out of 659
# completed: 83 out of 659
# completed: 84 out of 659
# completed: 85 out of 659
# completed: 86 out of 659
# completed: 87 out of 659
# completed: 88 out of 659
# completed: 89 out of 659
# completed: 90 out of 659
# completed: 91 out of 659
# completed: 92 out of 659
# completed: 93 out of 659
# completed: 94 out of 659
# completed: 95 out of 659
# completed: 96 out of 659
# completed: 97 out of 659
# completed: 98 out of 659
# completed: 99 out of 659
# completed: 100 out of 659
# completed: 101 out of 659
# completed: 102 out of 659
# completed: 103 out of 659
# completed: 104 out of 659
# completed: 105 out of 659
# completed: 106 out of 659
# completed: 107 out of 659
# completed: 108 out of 659
# completed: 109 out of 659
# completed: 110 out of 659
# completed: 111 out of 659
# completed: 112 out of 659
# completed: 113 out of 659
# completed: 114 out of 659
# completed: 115 out of 659
# completed: 116 out of 659
# completed: 117 out of 659
# completed: 118 out of 659
# completed: 119 out of 659
# completed: 120 out of 659
# completed: 121 out of 659
# completed: 122 out of 659
# completed: 123 out of 659
# completed: 124 out of 659
# completed: 125 out of 659
# completed: 126 out of 659
# completed: 127 out of 659
# completed: 128 out of 659
# completed: 129 out of 659
# completed: 130 out of 659
# completed: 131 out of 659
# completed: 132 out of 659
# completed: 133 out of 659
# completed: 134 out of 659
# completed: 135 out of 659
# completed: 136 out of 659
# completed: 137 out of 659
# completed: 138 out of 659
# completed: 139 out of 659
# completed: 140 out of 659
# completed: 141 out of 659
# completed: 142 out of 659
# completed: 143 out of 659
# completed: 144 out of 659
# completed: 145 out of 659
# completed: 146 out of 659
# completed: 147 out of 659
# completed: 148 out of 659
# completed: 149 out of 659
# completed: 150 out of 659
# completed: 151 out of 659
# completed: 152 out of 659
# completed: 153 out of 659
# completed: 154 out of 659
# completed: 155 out of 659
# completed: 156 out of 659
# completed: 157 out of 659
# completed: 158 out of 659
# completed: 159 out of 659
# completed: 160 out of 659
# completed: 161 out of 659
# completed: 162 out of 659
# completed: 163 out of 659
# completed: 164 out of 659
# completed: 165 out of 659
# completed: 166 out of 659
# completed: 167 out of 659
# completed: 168 out of 659
# completed: 169 out of 659
# completed: 170 out of 659
# completed: 171 out of 659
# completed: 172 out of 659
# completed: 173 out of 659
# completed: 174 out of 659
# completed: 175 out of 659
# completed: 176 out of 659
# completed: 177 out of 659
# completed: 178 out of 659
# completed: 179 out of 659
# completed: 180 out of 659
# completed: 181 out of 659
# completed: 182 out of 659
# completed: 183 out of 659
# completed: 184 out of 659
# completed: 185 out of 659
# completed: 186 out of 659
# completed: 187 out of 659
# completed: 188 out of 659
# completed: 189 out of 659
# completed: 190 out of 659
# completed: 191 out of 659
# completed: 192 out of 659
# completed: 193 out of 659
# completed: 194 out of 659
# completed: 195 out of 659
# completed: 196 out of 659
# completed: 197 out of 659
# completed: 198 out of 659
# completed: 199 out of 659
# completed: 200 out of 659
# completed: 201 out of 659
# completed: 202 out of 659
# completed: 203 out of 659
# completed: 204 out of 659
# completed: 205 out of 659
# completed: 206 out of 659
# completed: 207 out of 659
# completed: 208 out of 659
# completed: 209 out of 659
# completed: 210 out of 659
# completed: 211 out of 659
# completed: 212 out of 659
# completed: 213 out of 659
# completed: 214 out of 659
# completed: 215 out of 659
# completed: 216 out of 659
# completed: 217 out of 659
# completed: 218 out of 659
# completed: 219 out of 659
# completed: 220 out of 659
# completed: 221 out of 659
# completed: 222 out of 659
# completed: 223 out of 659
# completed: 224 out of 659
# completed: 225 out of 659
# completed: 226 out of 659
# completed: 227 out of 659
# completed: 228 out of 659
# completed: 229 out of 659
# completed: 230 out of 659
# completed: 231 out of 659
# completed: 232 out of 659
# completed: 233 out of 659
# completed: 234 out of 659
# completed: 235 out of 659
# completed: 236 out of 659
# completed: 237 out of 659
# completed: 238 out of 659
# completed: 239 out of 659
# completed: 240 out of 659
# completed: 241 out of 659
# completed: 242 out of 659
# completed: 243 out of 659
# completed: 244 out of 659
# completed: 245 out of 659
# completed: 246 out of 659
# completed: 247 out of 659
# completed: 248 out of 659
# completed: 249 out of 659
# completed: 250 out of 659
# completed: 251 out of 659
# completed: 252 out of 659
# completed: 253 out of 659
# completed: 254 out of 659
# completed: 255 out of 659
# completed: 256 out of 659
# completed: 257 out of 659
# completed: 258 out of 659
# completed: 259 out of 659
# completed: 260 out of 659
# completed: 261 out of 659
# completed: 262 out of 659
# completed: 263 out of 659
# completed: 264 out of 659
# completed: 265 out of 659
# completed: 266 out of 659
# completed: 267 out of 659
# completed: 268 out of 659
# completed: 269 out of 659
# completed: 270 out of 659
# completed: 271 out of 659
# completed: 272 out of 659
# completed: 273 out of 659
# completed: 274 out of 659
# completed: 275 out of 659
# completed: 276 out of 659
# completed: 277 out of 659
# completed: 278 out of 659
# completed: 279 out of 659
# completed: 280 out of 659
# completed: 281 out of 659
# completed: 282 out of 659
# completed: 283 out of 659
# completed: 284 out of 659
# completed: 285 out of 659
# completed: 286 out of 659
# completed: 287 out of 659
# completed: 288 out of 659
# completed: 289 out of 659
# completed: 290 out of 659
# completed: 291 out of 659
# completed: 292 out of 659
# completed: 293 out of 659
# completed: 294 out of 659
# completed: 295 out of 659
# completed: 296 out of 659
# completed: 297 out of 659
# completed: 298 out of 659
# completed: 299 out of 659
# completed: 300 out of 659
# completed: 301 out of 659
# completed: 302 out of 659
# completed: 303 out of 659
# completed: 304 out of 659
# completed: 305 out of 659
# completed: 306 out of 659
# completed: 307 out of 659
# completed: 308 out of 659
# completed: 309 out of 659
# completed: 310 out of 659
# completed: 311 out of 659
# completed: 312 out of 659
# completed: 313 out of 659
# completed: 314 out of 659
# completed: 315 out of 659
# completed: 316 out of 659
# completed: 317 out of 659
# completed: 318 out of 659
# completed: 319 out of 659
# completed: 320 out of 659
# completed: 321 out of 659
# completed: 322 out of 659
# completed: 323 out of 659
# completed: 324 out of 659
# completed: 325 out of 659
# completed: 326 out of 659
# completed: 327 out of 659
# completed: 328 out of 659
# completed: 329 out of 659
# completed: 330 out of 659
# completed: 331 out of 659
# completed: 332 out of 659
# completed: 333 out of 659
# completed: 334 out of 659
# completed: 335 out of 659
# completed: 336 out of 659
# completed: 337 out of 659
# completed: 338 out of 659
# completed: 339 out of 659
# completed: 340 out of 659
# completed: 341 out of 659
# completed: 342 out of 659
# completed: 343 out of 659
# completed: 344 out of 659
# completed: 345 out of 659
# completed: 346 out of 659
# completed: 347 out of 659
# completed: 348 out of 659
# completed: 349 out of 659
# completed: 350 out of 659
# completed: 351 out of 659
# completed: 352 out of 659
# completed: 353 out of 659
# completed: 354 out of 659
# completed: 355 out of 659
# completed: 356 out of 659
# completed: 357 out of 659
# completed: 358 out of 659
# completed: 359 out of 659
# completed: 360 out of 659
# completed: 361 out of 659
# completed: 362 out of 659
# completed: 363 out of 659
# completed: 364 out of 659
# completed: 365 out of 659
# completed: 366 out of 659
# completed: 367 out of 659
# completed: 368 out of 659
# completed: 369 out of 659
# completed: 370 out of 659
# completed: 371 out of 659
# completed: 372 out of 659
# completed: 373 out of 659
# completed: 374 out of 659
# completed: 375 out of 659
# completed: 376 out of 659
# completed: 377 out of 659
# completed: 378 out of 659
# completed: 379 out of 659
# completed: 380 out of 659
# completed: 381 out of 659
# completed: 382 out of 659
# completed: 383 out of 659
# completed: 384 out of 659
# completed: 385 out of 659
# completed: 386 out of 659
# completed: 387 out of 659
# completed: 388 out of 659
# completed: 389 out of 659
# completed: 390 out of 659
# completed: 391 out of 659
# completed: 392 out of 659
# completed: 393 out of 659
# completed: 394 out of 659
# completed: 395 out of 659
# completed: 396 out of 659
# completed: 397 out of 659
# completed: 398 out of 659
# completed: 399 out of 659
# completed: 400 out of 659
# completed: 401 out of 659
# completed: 402 out of 659
# completed: 403 out of 659
# completed: 404 out of 659
# completed: 405 out of 659
# completed: 406 out of 659
# completed: 407 out of 659
# completed: 408 out of 659
# completed: 409 out of 659
# completed: 410 out of 659
# completed: 411 out of 659
# completed: 412 out of 659
# completed: 413 out of 659
# completed: 414 out of 659
# completed: 415 out of 659
# completed: 416 out of 659
# completed: 417 out of 659
# completed: 418 out of 659
# completed: 419 out of 659
# completed: 420 out of 659
# completed: 421 out of 659
# completed: 422 out of 659
# completed: 423 out of 659
# completed: 424 out of 659
# completed: 425 out of 659
# completed: 426 out of 659
# completed: 427 out of 659
# completed: 428 out of 659
# completed: 429 out of 659
# completed: 430 out of 659
# completed: 431 out of 659
# completed: 432 out of 659
# completed: 433 out of 659
# completed: 434 out of 659
# completed: 435 out of 659
# completed: 436 out of 659
# completed: 437 out of 659
# completed: 438 out of 659
# completed: 439 out of 659
# completed: 440 out of 659
# completed: 441 out of 659
# completed: 442 out of 659
# completed: 443 out of 659
# completed: 444 out of 659
# completed: 445 out of 659
# completed: 446 out of 659
# completed: 447 out of 659
# completed: 448 out of 659
# completed: 449 out of 659
# completed: 450 out of 659
# completed: 451 out of 659
# completed: 452 out of 659
# completed: 453 out of 659
# completed: 454 out of 659
# completed: 455 out of 659
# completed: 456 out of 659
# completed: 457 out of 659
# completed: 458 out of 659
# completed: 459 out of 659
# completed: 460 out of 659
# completed: 461 out of 659
# completed: 462 out of 659
# completed: 463 out of 659
# completed: 464 out of 659
# completed: 465 out of 659
# completed: 466 out of 659
# completed: 467 out of 659
# completed: 468 out of 659
# completed: 469 out of 659
# completed: 470 out of 659
# completed: 471 out of 659
# completed: 472 out of 659
# completed: 473 out of 659
# completed: 474 out of 659
# completed: 475 out of 659
# completed: 476 out of 659
# completed: 477 out of 659
# completed: 478 out of 659
# completed: 479 out of 659
# completed: 480 out of 659
# completed: 481 out of 659
# completed: 482 out of 659
# completed: 483 out of 659
# completed: 484 out of 659
# completed: 485 out of 659
# completed: 486 out of 659
# completed: 487 out of 659
# completed: 488 out of 659
# completed: 489 out of 659
# completed: 490 out of 659
# completed: 491 out of 659
# completed: 492 out of 659
# completed: 493 out of 659
# completed: 494 out of 659
# completed: 495 out of 659
# completed: 496 out of 659
# completed: 497 out of 659
# completed: 498 out of 659
# completed: 499 out of 659
# completed: 500 out of 659
# completed: 501 out of 659
# completed: 502 out of 659
# completed: 503 out of 659
# completed: 504 out of 659
# completed: 505 out of 659
# completed: 506 out of 659
# completed: 507 out of 659
# completed: 508 out of 659
# completed: 509 out of 659
# completed: 510 out of 659
# completed: 511 out of 659
# completed: 512 out of 659
# completed: 513 out of 659
# completed: 514 out of 659
# completed: 515 out of 659
# completed: 516 out of 659
# completed: 517 out of 659
# completed: 518 out of 659
# completed: 519 out of 659
# completed: 520 out of 659
# completed: 521 out of 659
# completed: 522 out of 659
# completed: 523 out of 659
# completed: 524 out of 659
# completed: 525 out of 659
# completed: 526 out of 659
# completed: 527 out of 659
# completed: 528 out of 659
# completed: 529 out of 659
# completed: 530 out of 659
# completed: 531 out of 659
# completed: 532 out of 659
# completed: 533 out of 659
# completed: 534 out of 659
# completed: 535 out of 659
# completed: 536 out of 659
# completed: 537 out of 659
# completed: 538 out of 659
# completed: 539 out of 659
# completed: 540 out of 659
# completed: 541 out of 659
# completed: 542 out of 659
# completed: 543 out of 659
# completed: 544 out of 659
# completed: 545 out of 659
# completed: 546 out of 659
# completed: 547 out of 659
# completed: 548 out of 659
# completed: 549 out of 659
# completed: 550 out of 659
# completed: 551 out of 659
# completed: 552 out of 659
# completed: 553 out of 659
# completed: 554 out of 659
# completed: 555 out of 659
# completed: 556 out of 659
# completed: 557 out of 659
# completed: 558 out of 659
# completed: 559 out of 659
# completed: 560 out of 659
# completed: 561 out of 659
# completed: 562 out of 659
# completed: 563 out of 659
# completed: 564 out of 659
# completed: 565 out of 659
# completed: 566 out of 659
# completed: 567 out of 659
# completed: 568 out of 659
# completed: 569 out of 659
# completed: 570 out of 659
# completed: 571 out of 659
# completed: 572 out of 659
# completed: 573 out of 659
# completed: 574 out of 659
# completed: 575 out of 659
# completed: 576 out of 659
# completed: 577 out of 659
# completed: 578 out of 659
# completed: 579 out of 659
# completed: 580 out of 659
# completed: 581 out of 659
# completed: 582 out of 659
# completed: 583 out of 659
# completed: 584 out of 659
# completed: 585 out of 659
# completed: 586 out of 659
# completed: 587 out of 659
# completed: 588 out of 659
# completed: 589 out of 659
# completed: 590 out of 659
# completed: 591 out of 659
# completed: 592 out of 659
# completed: 593 out of 659
# completed: 594 out of 659
# completed: 595 out of 659
# completed: 596 out of 659
# completed: 597 out of 659
# completed: 598 out of 659
# completed: 599 out of 659
# completed: 600 out of 659
# completed: 601 out of 659
# completed: 602 out of 659
# completed: 603 out of 659
# completed: 604 out of 659
# completed: 605 out of 659
# completed: 606 out of 659
# completed: 607 out of 659
# completed: 608 out of 659
# completed: 609 out of 659
# completed: 610 out of 659
# completed: 611 out of 659
# completed: 612 out of 659
# completed: 613 out of 659
# completed: 614 out of 659
# completed: 615 out of 659
# completed: 616 out of 659
# completed: 617 out of 659
# completed: 618 out of 659
# completed: 619 out of 659
# completed: 620 out of 659
# completed: 621 out of 659
# completed: 622 out of 659
# completed: 623 out of 659
# completed: 624 out of 659
# completed: 625 out of 659
# completed: 626 out of 659
# completed: 627 out of 659
# completed: 628 out of 659
# completed: 629 out of 659
# completed: 630 out of 659
# completed: 631 out of 659
# completed: 632 out of 659
# completed: 633 out of 659
# completed: 634 out of 659
# completed: 635 out of 659
# completed: 636 out of 659
# completed: 637 out of 659
# completed: 638 out of 659
# completed: 639 out of 659
# completed: 640 out of 659
# completed: 641 out of 659
# completed: 642 out of 659
# completed: 643 out of 659
# completed: 644 out of 659
# completed: 645 out of 659
# completed: 646 out of 659
# completed: 647 out of 659
# completed: 648 out of 659
# completed: 649 out of 659
# completed: 650 out of 659
# completed: 651 out of 659
# completed: 652 out of 659
# completed: 653 out of 659
# completed: 654 out of 659
# completed: 655 out of 659
# completed: 656 out of 659
# completed: 657 out of 659
# completed: 658 out of 659
# completed: 659 out of 659

# %% [markdown]
# ## 1.5. Creating the Cryptocurrency DataFrame
#
# After scraping the data for multiple dates, we now populate our main DataFrame with the collected lists.
# Each list corresponds to a specific attribute of the cryptocurrencies, such as name, symbol, market cap, price, and percentage changes.
#
# This step consolidates all the scraped data into a structured format suitable for further processing and analysis.

# %%
# Populate DataFrame with scraped data
df['Date'] = crypto_date_list
df['Name'] = crypto_name_list
df['Symbol'] = crypto_symbol_list
df['Market Cap'] = crypto_market_cap_list
df['Price'] = crypto_price_list
df['Circulating Supply'] = crypto_circulating_supply_list
df['Volume (24hr)'] = crypto_voulume_24hr_list
df['% 1h'] = crypto_pct_1hr_list
df['% 24h'] = crypto_pct_24hr_list
df['% 7d'] = crypto_pct_7day_list

df
# Out:
#                        Date       Name Symbol          Market Cap    Price  \
# 0     /historical/20130428/    Bitcoin    BTC   $1,488,566,971.96  $134.21
# 1     /historical/20130428/   Litecoin    LTC      $74,637,021.57  $4.3484
# 2     /historical/20130428/   Peercoin    PPC       $7,250,186.65  $0.3865
# 3     /historical/20130428/   Namecoin    NMC       $5,995,997.19  $1.1072
# 4     /historical/20130428/  Terracoin    TRC       $1,503,099.40  $0.6469
# ...                     ...        ...    ...                 ...      ...
# 6582  /historical/20251207/       USDC   USDC  $78,198,364,307.09  $1.0001
# 6583  /historical/20251207/     Solana    SOL  $74,055,834,015.84  $132.09
# 6584  /historical/20251207/       TRON    TRX  $27,163,787,850.16  $0.2869
# 6585  /historical/20251207/   Dogecoin   DOGE  $22,395,155,616.57  $0.1386
# 6586  /historical/20251207/    Cardano    ADA  $14,964,661,330.58  $0.4168
#
#      Circulating Supply      Volume (24hr)    % 1h   % 24h    % 7d
# 0            11,091,325               None   0.64%      --      --
# 1            17,164,230               None   0.80%      --      --
# 2            18,757,362               None  -0.93%      --      --
# 3             5,415,300               None  -0.05%      --      --
# 4             2,323,570               None   0.61%      --      --
# ...                 ...                ...     ...     ...     ...
# 6582     78,192,824,319  $7,817,626,806.69  -0.01%  <0.01%   0.03%
# 6583        560,631,621  $3,824,892,146.92   0.63%  -0.19%  -1.10%
# 6584     94,681,527,841    $523,906,170.03   0.21%  -0.18%   1.85%
# 6585    161,608,712,799  $1,065,448,744.32   0.51%  -0.83%  -5.52%
# 6586     35,902,711,181    $609,158,161.58   0.27%   0.70%   0.22%
#
# [6587 rows x 10 columns]

# %% [markdown]
# ## 1.6 DataFrame Information Before Transformation
#
# Before performing any preprocessing or handling missing values, it is important to inspect the structure of the scraped dataset.
# The `df.info()` method provides details such as:
#
# - Number of rows
# - Column names
# - Non-null counts
# - Data types
# - Memory usage
#
# This helps identify columns containing missing values, ensuring that appropriate preprocessing steps can be applied later.

# %%
# Display DataFrame information before transformation
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6587 entries, 0 to 6586
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                6587 non-null   object
#  1   Name                6587 non-null   object
#  2   Symbol              6587 non-null   object
#  3   Market Cap          6587 non-null   object
#  4   Price               6587 non-null   object
#  5   Circulating Supply  6587 non-null   object
#  6   Volume (24hr)       6240 non-null   object
#  7   % 1h                6587 non-null   object
#  8   % 24h               6587 non-null   object
#  9   % 7d                6587 non-null   object
# dtypes: object(10)
# memory usage: 514.7+ KB

# %% [markdown]
# ## 2. Transformation
# ### 2.1. Data Cleaning and Formatting
#
# After collecting the raw cryptocurrency data, several preprocessing steps are required to convert the scraped text values into clean numerical formats suitable for analysis and machine learning.
# The following transformations are applied:
#
# - **Date parsing:** Convert scraped URL-style date strings into Python datetime format.
# - **String cleaning:** Remove symbols such as `$`, `,`, `%`, `--`, `<`, `>` from numeric fields.
# - **Type conversion:** Convert cleaned values into numeric data types.
# - **Special handling:** Replace values like `<0.01` and `--` with meaningful numerical substitutes.
# - **Formatting:** Apply consistent display formatting for readability.

# %%
# Extract the date component from the 'Date' column and convert it to a datetime data type
df['Date'] = pd.to_datetime(df['Date'].str.split('/').str[-2], format='%Y%m%d')

# Replace the dollar signs ($) and commas (,) from the 'Market Cap' and 'Price' columns
df['Market Cap'] = df['Market Cap'].str.replace('[$,]', '', regex=True)
df['Price'] = df['Price'].str.replace('[$,]', '', regex=True)

# Replace the commas (,) from the 'Circulating Supply' column
df['Circulating Supply'] = df['Circulating Supply'].str.replace(',', '')

# Replace the dollar signs ($) and commas (,) from the 'Volume (24hr)' columns
df['Volume (24hr)'] = df['Volume (24hr)'].str.replace('[$,]', '', regex=True)

# Replace the unchange sign (--), the smaller sign (<), the larger sign (>) and percentage sign (%) from the '% 1h', '% 24h', and '% 7d' columns
df['% 1h'] = df['% 1h'].str.replace('--', '0').str.lstrip('>').str.lstrip('<').str.rstrip('%')
df['% 24h'] = df['% 24h'].str.replace('--', '0').str.lstrip('>').str.lstrip('<').str.rstrip('%')
df['% 7d'] = df['% 7d'].str.replace('--', '0').str.lstrip('>').str.lstrip('<').str.rstrip('%')

# Convert the numeric columns to appropriate data types, replacing invalid values with NaN
numeric_cols = ['Market Cap', 'Price', 'Circulating Supply', 'Volume (24hr)', '% 1h', '% 24h', '% 7d']
df[numeric_cols] = df[numeric_cols].apply(lambda x: pd.to_numeric(x))

# Handle specific case of "<0.01" by replacing it with a small non-zero value, e.g., 0.005
df.loc[df['% 1h'] < 0, '% 1h'] = 0.005

# Set the display format for float and integer values
pd.options.display.float_format = '{:.2f}'.format

# Display the updated DataFrame
df
# Out:
#            Date       Name Symbol     Market Cap  Price  Circulating Supply  \
# 0    2013-04-28    Bitcoin    BTC  1488566971.96 134.21            11091325
# 1    2013-04-28   Litecoin    LTC    74637021.57   4.35            17164230
# 2    2013-04-28   Peercoin    PPC     7250186.65   0.39            18757362
# 3    2013-04-28   Namecoin    NMC     5995997.19   1.11             5415300
# 4    2013-04-28  Terracoin    TRC     1503099.40   0.65             2323570
# ...         ...        ...    ...            ...    ...                 ...
# 6582 2025-12-07       USDC   USDC 78198364307.09   1.00         78192824319
# 6583 2025-12-07     Solana    SOL 74055834015.84 132.09           560631621
# 6584 2025-12-07       TRON    TRX 27163787850.16   0.29         94681527841
# 6585 2025-12-07   Dogecoin   DOGE 22395155616.57   0.14        161608712799
# 6586 2025-12-07    Cardano    ADA 14964661330.58   0.42         35902711181
#
#       Volume (24hr)  % 1h  % 24h  % 7d
# 0               NaN  0.64   0.00  0.00
# 1               NaN  0.80   0.00  0.00
# 2               NaN  0.01   0.00  0.00
# 3               NaN  0.01   0.00  0.00
# 4               NaN  0.61   0.00  0.00
# ...             ...   ...    ...   ...
# 6582  7817626806.69  0.01   0.01  0.03
# 6583  3824892146.92  0.63  -0.19 -1.10
# 6584   523906170.03  0.21  -0.18  1.85
# 6585  1065448744.32  0.51  -0.83 -5.52
# 6586   609158161.58  0.27   0.70  0.22
#
# [6587 rows x 10 columns]

# %% [markdown]
# ## 2.2. Missing Value Imputation and Reverse Normalization
#
# The `Volume (24hr)` column contains missing values that need to be handled before analysis.
# Instead of removing rows or filling with simple statistics like mean or median, we can use **K-Nearest Neighbors (KNN) imputation**.
#
# **Why KNN?**
# - It predicts missing values based on the similarity of other numerical features.
# - More accurate than mean/median imputation.
# - Slightly more computationally intensive due to algorithmic calculations.

# %%
# Check for missing data
df.isnull().sum()
# Out:
# Date                    0
# Name                    0
# Symbol                  0
# Market Cap              0
# Price                   0
# Circulating Supply      0
# Volume (24hr)         347
# % 1h                    0
# % 24h                   0
# % 7d                    0
# dtype: int64

# %%
# Select numerical columns for imputation
numeric_cols = ['Market Cap', 'Price', 'Circulating Supply', '% 1h', '% 24h', '% 7d', 'Volume (24hr)']

# Normalization
scaler = MinMaxScaler()
df_normalized = df.copy()
df_normalized[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# KNN Imputation
imputer = KNNImputer(n_neighbors=3)
df_imputed = df_normalized.copy()
df_imputed[numeric_cols] = imputer.fit_transform(df_normalized[numeric_cols])

# Reverse normalization
df_imputed[numeric_cols] = scaler.inverse_transform(df_imputed[numeric_cols])

df = df_imputed.copy()
df
# Out:
#            Date       Name Symbol     Market Cap  Price  Circulating Supply  \
# 0    2013-04-28    Bitcoin    BTC  1488566971.96 134.21         11091325.00
# 1    2013-04-28   Litecoin    LTC    74637021.57   4.35         17164230.00
# 2    2013-04-28   Peercoin    PPC     7250186.65   0.39         18757362.00
# 3    2013-04-28   Namecoin    NMC     5995997.19   1.11          5415300.00
# 4    2013-04-28  Terracoin    TRC     1503099.40   0.65          2323570.00
# ...         ...        ...    ...            ...    ...                 ...
# 6582 2025-12-07       USDC   USDC 78198364307.09   1.00      78192824319.00
# 6583 2025-12-07     Solana    SOL 74055834015.84 132.09        560631621.00
# 6584 2025-12-07       TRON    TRX 27163787850.16   0.29      94681527841.00
# 6585 2025-12-07   Dogecoin   DOGE 22395155616.57   0.14     161608712799.00
# 6586 2025-12-07    Cardano    ADA 14964661330.58   0.42      35902711181.00
#
#       Volume (24hr)  % 1h  % 24h  % 7d
# 0      207329643.26  0.64   0.00  0.00
# 1      208620175.73  0.80   0.00  0.00
# 2        5939582.36  0.01   0.00  0.00
# 3        5939582.36  0.01   0.00  0.00
# 4       94459172.69  0.61   0.00  0.00
# ...             ...   ...    ...   ...
# 6582  7817626806.69  0.01   0.01  0.03
# 6583  3824892146.92  0.63  -0.19 -1.10
# 6584   523906170.03  0.21  -0.18  1.85
# 6585  1065448744.32  0.51  -0.83 -5.52
# 6586   609158161.58  0.27   0.70  0.22
#
# [6587 rows x 10 columns]

# %% [markdown]
# ## 2.3. DataFrame Information After Transformation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6587 entries, 0 to 6586
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                6587 non-null   datetime64[ns]
#  1   Name                6587 non-null   object
#  2   Symbol              6587 non-null   object
#  3   Market Cap          6587 non-null   float64
#  4   Price               6587 non-null   float64
#  5   Circulating Supply  6587 non-null   float64
#  6   Volume (24hr)       6587 non-null   float64
#  7   % 1h                6587 non-null   float64
#  8   % 24h               6587 non-null   float64
#  9   % 7d                6587 non-null   float64
# dtypes: datetime64[ns](1), float64(7), object(2)
# memory usage: 514.7+ KB

# %% [markdown]
# After performing data cleaning, formatting, and KNN imputation, the dataset is now fully transformed.
# All columns are in their appropriate data types and missing values have been handled:

# %% [markdown]
# ## 3. Save Processed Data to CSV

# %%
# Save the DataFrame as a CSV file
df.to_csv('historical_crypto_sundays.csv', index=False)

# %% [markdown]
# ## 📌 01_web_scraping.ipynb --> Section Summary
#
# In this notebook, we successfully completed the **web scraping, cleaning, transformation, and preparation** of historical cryptocurrency data (top 10 coins weekly) from CoinMarketCap spanning **2013 to 2025 (7th December)**.
#
# Key accomplishments:
#
# 1. **Data Collection**
#    - Scraped weekly cryptocurrency data including: `Date`, `Name`, `Symbol`, `Market Cap`, `Price`, `Circulating Supply`, `Volume (24hr)`, and percentage changes (`% 1h`, `% 24h`, `% 7d`).
#    - Ensured extraction of top-performing coins for each week and consistent structure for analysis.
#
# 2. **Data Cleaning & Formatting**
#    - Converted string values to appropriate numeric formats.
#    - Removed symbols like `$`, `,`, `%`, `<`, `>`, and handled placeholders like `--`.
#    - Parsed dates from URL-style strings to `datetime` objects.
#    - Applied consistent float formatting for better readability.
#
# 3. **Missing Value Imputation**
#    - Identified missing values, primarily in the `Volume (24hr)` column.
#    - Applied **K-Nearest Neighbors (KNN) imputation** after normalizing numerical columns.
#    - Successfully filled missing values and reversed normalization to retain original scale.
#
# 4. **Data Type Transformation**
#    - All numeric columns (`Market Cap`, `Price`, `Circulating Supply`, `Volume (24hr)`, `% 1h`, `% 24h`, `% 7d`) were converted to `float64`.
#    - `Date` column is in `datetime64[ns]` format.
#    - Data is now fully structured and ready for downstream analysis.
#
# 5. **Data Export**
#    - Saved the fully cleaned and transformed dataset as `historical_crypto_sundays.csv` for further use in **Power BI, SQL databases, or other analytical tools**.
#
# **Outcome:**
# The dataset is now complete, accurate, and formatted for **visual analytics, trend analysis, and interactive dashboards**. This forms a solid foundation for creating professional cryptocurrency market insights and investment dashboards.
#
# ---
